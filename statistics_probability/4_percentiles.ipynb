# %%
import numpy as np 
import matplotlib.pyplot as plt

vals=np.random.normal(0,0.5,10000)
plt.hist(vals,50,edgecolor='black')
# Out:
# (array([  3.,   0.,   1.,   2.,   4.,   7.,   8.,  21.,  23.,  45.,  64.,
#          93., 132., 162., 194., 254., 336., 367., 356., 485., 492., 545.,
#         565., 645., 615., 621., 581., 534., 515., 441., 371., 334., 285.,
#         223., 178., 122., 115.,  75.,  62.,  45.,  20.,  23.,  14.,  10.,
#           4.,   2.,   3.,   2.,   0.,   1.]),
#  array([-1.87335874, -1.7960452 , -1.71873167, -1.64141814, -1.56410461,
#         -1.48679107, -1.40947754, -1.33216401, -1.25485048, -1.17753694,
#         -1.10022341, -1.02290988, -0.94559635, -0.86828281, -0.79096928,
#         -0.71365575, -0.63634222, -0.55902868, -0.48171515, -0.40440162,
#         -0.32708809, -0.24977455, -0.17246102, -0.09514749, -0.01783396,
#          0.05947958,  0.13679311,  0.21410664,  0.29142017,  0.36873371,
#          0.44604724,  0.52336077,  0.6006743 ,  0.67798784,  0.75530137,
#          0.8326149 ,  0.90992843,  0.98724197,  1.0645555 ,  1.14186903,
#          1.21918256,  1.2964961 ,  1.37380963,  1.45112316,  1.52843669,
#          1.60575022,  1.68306376,  1.76037729,  1.83769082,  1.91500435,
#          1.99231789]),
#  <BarContainer object of 50 artists>)

# %%
np.percentile(vals,50)
#np.percentile(vals,90)
# Out:
# 0.0046453824915250975
